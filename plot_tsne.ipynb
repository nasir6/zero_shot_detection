# %%
import scipy.io as sio
from sklearn import datasets
from sklearn.manifold import TSNE
import numpy as np
from matplotlib import pyplot as plt

# %%
root = 'data/coco'
features = np.load(f"{root}/all_coco_seen_feats.npy")
labels = np.load(f"{root}/all_coco_seen_labels.npy")

# %%
tsne = TSNE(n_components=2, random_state=0)
X = features
y = labels
targets = np.unique(y)

from random import randint
colors = []
for i in range(targets.shape[0]):
    colors.append('#%06X' % randint(0, 0xFFFFFF))
    
print(features.shape, y.shape, targets.shape)
# Out:
# (31543296, 1024) (31543296,) (66,)

# %%
fg_labels = y > 0
X = X[fg_labels]
y = y[fg_labels]
print(X.shape, y.shape, targets.shape)
# Out:
# (4811720, 1024) (4811720,) (66,)

# %%
# subset
X_sub = X[:3000]
y_sub = y[:3000]

# %%
X_2d = tsne.fit_transform(X_sub)

# %%
plt.figure(figsize=(6, 5))
for i, c in zip(targets, colors):
    plt.scatter(X_2d[y_sub == i, 0], X_2d[y_sub == i, 1], c=c)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
syn_feature = np.load('syn_feature.npy')
syn_label = np.load('syn_label.npy')

# %%
syn_label.shape
# Out:
# (76800,)

# %%
tsne = TSNE(n_components=2, random_state=0)
X = syn_feature
y = syn_label
targets = np.unique(y)

from random import randint
colors = []
for i in range(targets.shape[0]):
    colors.append('#%06X' % randint(0, 0xFFFFFF))
    
print(X.shape, y.shape, targets.shape)
# Out:
# (76800, 1024) (76800,) (15,)

# %%
# subset
X_sub = X
y_sub = y
# [:3000]

# %%
X_2d = tsne.fit_transform(X_sub)

# %%
fig = plt.figure(figsize=(6, 5))
for i, c in zip(targets, colors):
    plt.scatter(X_2d[y_sub == i, 0], X_2d[y_sub == i, 1], c=c)
plt.legend()
# plt.show()
fig.savefig('temp.png')

# %%
plt.scatter(X_2d[:, 0], X_2d[:, 1])

# %%
fg_labels = y > 0
X = X[fg_labels]
y = y[fg_labels]

colors = []
for i in range(targets.shape[0]):
    colors.append('#%06X' % randint(0, 0xFFFFFF))
    

X_2d = tsne.fit_transform(X)

plt.figure(figsize=(6, 5))
# colors = 'r', 'g', 'b', 'c', 'm', 'y', 'k', 'w', 'orange', 'purple'
for i, c in zip(labels, colors):
    plt.scatter(X_2d[y == i, 0], X_2d[y == i, 1], c=c)
plt.legend()
plt.show()

# %%
dataroot = '/home/nasir/Downloads/cvpr18xian/data/'
dataset = 'FLO'
image_embedding = 'res101'

# %%
matcontent = sio.loadmat(dataroot + "/" + dataset + "/" + image_embedding + ".mat")
feature = matcontent['features'].T
label = matcontent['labels'].astype(int).squeeze() - 1
from random import randint
colors = []
labels = np.unique(y)
for i in range(labels.shape[0]):
    colors.append('#%06X' % randint(0, 0xFFFFFF))

# %%
# Out:
# ((8189, 2048), (8189,), (102,))

# %%
# %matplotlib inline

# %%
tsne = TSNE(n_components=2, random_state=0)

# %%
X = feature
y = label
X_2d = tsne.fit_transform(X)

# %%
plt.figure(figsize=(6, 5))
# colors = 'r', 'g', 'b', 'c', 'm', 'y', 'k', 'w', 'orange', 'purple'
for i, c in zip(labels, colors):
    plt.scatter(X_2d[y == i, 0], X_2d[y == i, 1], c=c)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
digits = datasets.load_digits()
# Take the first 500 data points: it's hard to see 1500 points
X = digits.data[:500]
y = digits.target[:500]
X_2d = tsne.fit_transform(X)

target_ids = range(len(digits.target_names))

from matplotlib import pyplot as plt
plt.figure(figsize=(6, 5))
colors = 'r', 'g', 'b', 'c', 'm', 'y', 'k', 'w', 'orange', 'purple'
for i, c, label in zip(target_ids, colors, digits.target_names):
    plt.scatter(X_2d[y == i, 0], X_2d[y == i, 1], c=c, label=label)
plt.legend()
plt.show()

# %% [markdown]
# Fit and transform with a TSNE
