# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv

# %%
config_file = '../configs/faster_rcnn_r101_fpn_1x.py'
# download the checkpoint from model zoo and put it in `checkpoints/`
checkpoint_file = '../work_dirs/faster_rcnn_r101_fpn_1x/epoch_12.pth'
# checkpoint_file = '../checkpoints/faster_rcnn_r50_fpn_1x_20181010-3d1b3351.pth'

# %%
# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')

# %%
# test a single image
img = 'demo.jpg'
result = inference_detector(model, img)
# Out:
# > /raid/mun/codes/zero_shot_detection/cvpr18xian/mmdetection/mmdet/models/detectors/two_stage.py(269)simple_test()
# -> x = self.extract_feat(img)
# (Pdb) n
# > /raid/mun/codes/zero_shot_detection/cvpr18xian/mmdetection/mmdet/models/detectors/two_stage.py(272)simple_test()
# -> x, img_meta, self.test_cfg.rpn) if proposals is None else proposals
# (Pdb) n
# > /raid/mun/codes/zero_shot_detection/cvpr18xian/mmdetection/mmdet/models/detectors/two_stage.py(274)simple_test()
# -> det_bboxes, det_labels = self.simple_test_bboxes(
# (Pdb) n
# > /raid/mun/codes/zero_shot_detection/cvpr18xian/mmdetection/mmdet/models/detectors/two_stage.py(275)simple_test()
# -> x, img_meta, proposal_list, self.test_cfg.rcnn, rescale=rescale)
# (Pdb) n
# > /raid/mun/codes/zero_shot_detection/cvpr18xian/mmdetection/mmdet/models/detectors/two_stage.py(276)simple_test()
# -> bbox_results = bbox2result(det_bboxes, det_labels,
# (Pdb) det_bboxes
# tensor([[3.7506e+02, 1.1855e+02, 3.8169e+02, 1.3892e+02, 4.0467e-01],
#         [6.2609e+02, 1.0542e+02, 6.3478e+02, 1.1526e+02, 1.4248e-01],
#         [2.3933e+02, 9.8927e+01, 2.4818e+02, 1.0761e+02, 5.5913e-02],
#         [3.2882e+02, 1.1875e+02, 3.4819e+02, 1.2775e+02, 5.3617e-02],
#         [2.4160e+02, 1.1491e+02, 2.5358e+02, 1.2448e+02, 1.9204e-01],
#         [1.9010e+02, 1.0992e+02, 2.9644e+02, 1.5402e+02, 9.9292e-01],
#         [2.6545e+02, 1.0614e+02, 3.2756e+02, 1.2561e+02, 9.7433e-01],
#         [6.0954e+02, 1.1267e+02, 6.3632e+02, 1.3647e+02, 9.9241e-01],
#         [4.8119e+02, 1.1066e+02, 5.2281e+02, 1.2975e+02, 9.9186e-01],
#         [9.8910e+01, 8.9762e+01, 1.1744e+02, 1.0003e+02, 9.5629e-01],
#         [5.7001e+02, 1.1026e+02, 5.9304e+02, 1.2627e+02, 9.6518e-01],
#         [1.4485e+02, 9.6673e+01, 1.6762e+02, 1.0425e+02, 9.4700e-01],
#         [3.9854e+02, 1.1077e+02, 4.3270e+02, 1.3178e+02, 9.8820e-01],
#         [6.1119e+01, 9.2809e+01, 8.2143e+01, 1.0483e+02, 9.6823e-01],
#         [8.9477e+01, 8.9555e+01, 1.0081e+02, 9.8188e+01, 3.2533e-01],
#         [8.3078e+01, 9.0020e+01, 9.8233e+01, 9.7442e+01, 8.8517e-01],
#         [5.9309e+02, 1.1061e+02, 6.1730e+02, 1.2475e+02, 9.4301e-01],
#         [2.2369e+02, 9.8314e+01, 2.4122e+02, 1.0629e+02, 8.3002e-01],
#         [5.3803e+02, 1.1465e+02, 5.4613e+02, 1.2467e+02, 9.3392e-02],
#         [6.7850e+01, 9.0357e+01, 8.4711e+01, 1.0303e+02, 7.0811e-02],
#         [5.4656e+02, 1.1118e+02, 5.9769e+02, 1.2692e+02, 3.7917e-01],
#         [9.4352e+01, 8.9890e+01, 1.5764e+02, 1.0098e+02, 1.5527e-01],
#         [2.2032e+02, 9.7429e+01, 2.5296e+02, 1.0889e+02, 1.0871e-01],
#         [8.2748e+01, 8.8898e+01, 1.1652e+02, 9.9727e+01, 9.3054e-02],
#         [1.2095e+02, 9.1140e+01, 1.6378e+02, 1.0406e+02, 8.8379e-02],
#         [6.6685e+01, 8.9258e+01, 1.0999e+02, 1.0159e+02, 9.6028e-02],
#         [1.7897e+02, 9.0129e+01, 2.2595e+02, 1.0851e+02, 1.2287e-01],
#         [1.7274e+02, 9.0542e+01, 2.2463e+02, 1.0856e+02, 8.3217e-02],
#         [5.6694e+02, 1.0979e+02, 5.9232e+02, 1.2672e+02, 5.4384e-02],
#         [4.3327e+02, 1.0489e+02, 4.8287e+02, 1.3148e+02, 6.3833e-02],
#         [2.0583e+02, 1.7754e+02, 4.5659e+02, 3.8939e+02, 9.6352e-01],
#         [3.7260e+02, 1.4730e+02, 4.3155e+02, 1.8779e+02, 5.7498e-01],
#         [3.7485e+02, 1.3354e+02, 4.3197e+02, 1.8683e+02, 8.7862e-01],
#         [2.1213e+02, 1.7917e+02, 4.5872e+02, 3.9072e+02, 1.5403e-01],
#         [3.7177e+02, 1.3753e+02, 4.3246e+02, 1.8758e+02, 8.5175e-02]],
#        device='cuda:0')
# (Pdb) det_bboxes.shape
# torch.Size([69, 5])
# (Pdb) proposal_list.shape
# *** AttributeError: 'list' object has no attribute 'shape'
# (Pdb) len(proposal_list)
# 1
# (Pdb) proposal_list[0].shape
# torch.Size([1000, 5])
# (Pdb) proposal_list[0][0]
# tensor([424.0997, 314.6359, 881.9629, 757.2261,   1.0000], device='cuda:0')
# (Pdb) bbox_results.shape
# *** NameError: name 'bbox_results' is not defined
# (Pdb) n
# > /raid/mun/codes/zero_shot_detection/cvpr18xian/mmdetection/mmdet/models/detectors/two_stage.py(277)simple_test()
# -> self.bbox_head.num_classes)
# (Pdb) bbox_results
# *** NameError: name 'bbox_results' is not defined
# (Pdb) n
# > /raid/mun/codes/zero_shot_detection/cvpr18xian/mmdetection/mmdet/models/detectors/two_stage.py(279)simple_test()
# -> if not self.with_mask:
# (Pdb) n
# > /raid/mun/codes/zero_shot_detection/cvpr18xian/mmdetection/mmdet/models/detectors/two_stage.py(280)simple_test()
# -> return bbox_results
# (Pdb) bbox_results
# [array([[3.75058838e+02, 1.18548279e+02, 3.81693512e+02, 1.38916351e+02,
#         4.04671133e-01],
#        [6.26092346e+02, 1.05419708e+02, 6.34776978e+02, 1.15256554e+02,
#         1.42482311e-01],
#        [2.39333527e+02, 9.89274673e+01, 2.48179855e+02, 1.07608925e+02,
#         5.59126586e-02],
#        [3.28815308e+02, 1.18750549e+02, 3.48191895e+02, 1.27748260e+02,
#         5.36171421e-02],
#        [2.41597305e+02, 1.14911545e+02, 2.53578796e+02, 1.24478569e+02,
type=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([[205.83109   , 177.54214   , 456.5935    , 389.38928   ,
#           0.96351665],
#        [372.59674   , 147.30005   , 431.54727   , 187.79485   ,
#           0.57497835]], dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([[374.8505   , 133.53523  , 431.97388  , 186.83089  ,   0.8786229]],
#       dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([[2.1213037e+02, 1.7917206e+02, 4.5872379e+02, 3.9072440e+02,
#         1.5402962e-01],
#        [3.7177219e+02, 1.3752870e+02, 4.3245609e+02, 1.8758109e+02,
#         8.5174665e-02]], dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32), array([], shape=(0, 5), dtype=float32)]
# (Pdb) bbox_results.shape
# *** AttributeError: 'list' object has no attribute 'shape'
# (Pdb) bbox_results[0].shape
# (5, 5)
# (Pdb) len(bbox_results)
# 80
# (Pdb) q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-4-4d78d4937daf> in <module>
#       1 # test a single image
#       2 img = 'demo.jpg'
# ----> 3 result = inference_detector(model, img)
#
# /raid/mun/codes/zero_shot_detection/cvpr18xian/mmdetection/mmdet/apis/inference.py in inference_detector(model, img)
#      84     # forward the model
#      85     with torch.no_grad():
# ---> 86         result = model(return_loss=False, rescale=True, **data)
#      87
#      88     return result
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /raid/mun/codes/zero_shot_detection/cvpr18xian/mmdetection/mmdet/core/fp16/decorators.py in new_func(*args, **kwargs)
#      47                                 'method of nn.Module')
#      48             if not (hasattr(args[0], 'fp16_enabled') and args[0].fp16_enabled):
# ---> 49                 return old_func(*args, **kwargs)
#      50             # get the arg spec of the decorated method
#      51             args_info = getfullargspec(old_func)
#
# /raid/mun/codes/zero_shot_detection/cvpr18xian/mmdetection/mmdet/models/detectors/faster_rcnn.py in forward(self, img, img_meta, return_loss, feats, classifier_only, **kwargs)
#      70             return self.forward_train(img, img_meta, **kwargs)
#      71         else:
# ---> 72             return self.forward_test(img, img_meta, **kwargs)
#      73
#      74     def feats_extract(self,
#
# /raid/mun/codes/zero_shot_detection/cvpr18xian/mmdetection/mmdet/models/detectors/base.py in forward_test(self, imgs, img_metas, **kwargs)
#     100
#     101         if num_augs == 1:
# --> 102             return self.simple_test(imgs[0], img_metas[0], **kwargs)
#     103         else:
#     104             return self.aug_test(imgs, img_metas, **kwargs)
#
# /raid/mun/codes/zero_shot_detection/cvpr18xian/mmdetection/mmdet/models/detectors/two_stage.py in simple_test(self, img, img_meta, proposals, rescale)
#     278
#     279         if not self.with_mask:
# --> 280             return bbox_results
#     281         else:
#     282             segm_results = self.simple_test_mask(
#
# /raid/mun/codes/zero_shot_detection/cvpr18xian/mmdetection/mmdet/models/detectors/two_stage.py in simple_test(self, img, img_meta, proposals, rescale)
#     278
#     279         if not self.with_mask:
# --> 280             return bbox_results
#     281         else:
#     282             segm_results = self.simple_test_mask(
#
# /opt/conda/lib/python3.7/bdb.py in trace_dispatch(self, frame, event, arg)
#      86             return # None
#      87         if event == 'line':
# ---> 88             return self.dispatch_line(frame)
#      89         if event == 'call':
#      90             return self.dispatch_call(frame, arg)
#
# /opt/conda/lib/python3.7/bdb.py in dispatch_line(self, frame)
#     111         if self.stop_here(frame) or self.break_here(frame):
#     112             self.user_line(frame)
# --> 113             if self.quitting: raise BdbQuit
#     114         return self.trace_dispatch
#     115
#
# BdbQuit:

# %%
# show the results
show_result_pyplot(img, result, model.CLASSES)
